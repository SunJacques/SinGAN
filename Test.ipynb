# %%
from PIL import Image
from matplotlib import pyplot as plt

# %%
scale_factor = 0.9
real = Image.open("img.jpeg")
w,h = real.size
real = real.resize((int(w*scale_factor),int(h*scale_factor)))

plt.imshow(real)
