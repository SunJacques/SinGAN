# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import pandas as pd

# %%
dfG = pd.read_csv('TrainedModels/balloons.jpeg/scale_factor=0.778132,alpha=9/G_plot.csv')
dfD = pd.read_csv('TrainedModels/balloons.jpeg/scale_factor=0.778132,alpha=9/D_plot.csv')
dfNoise = pd.read_csv('TrainedModels/balloons.jpeg/scale_factor=0.778132,alpha=9/noise_amp_plot.csv')
dfNoise = dfNoise.drop(dfNoise.columns[0], axis=1)

# %%
dfNoise
# Out:
#      scale 1   scale 2   scale 3   scale 4   scale 5   scale 6   scale 7  \
# 0    0.01128  0.007454  0.005112  0.004906  0.004403  0.004302  0.004079
# 1    0.01128  0.007454  0.005112  0.004906  0.004403  0.004302  0.004079
# 2    0.01128  0.007454  0.005112  0.004906  0.004403  0.004302  0.004079
# 3    0.01128  0.007454  0.005112  0.004906  0.004403  0.004302  0.004079
# 4    0.01128  0.007454  0.005112  0.004906  0.004403  0.004302  0.004079
# ..       ...       ...       ...       ...       ...       ...       ...
# 995  0.01128  0.007454  0.005112  0.004906  0.004403  0.004302  0.004079
# 996  0.01128  0.007454  0.005112  0.004906  0.004403  0.004302  0.004079
# 997  0.01128  0.007454  0.005112  0.004906  0.004403  0.004302  0.004079
# 998  0.01128  0.007454  0.005112  0.004906  0.004403  0.004302  0.004079
# 999  0.01128  0.007454  0.005112  0.004906  0.004403  0.004302  0.004079
#
#       scale 8
# 0    0.006569
# 1    0.006569
# 2    0.006569
# 3    0.006569
# 4    0.006569
# ..        ...
# 995  0.006569
# 996  0.006569
# 997  0.006569
# 998  0.006569
# 999  0.006569
#
# [1000 rows x 8 columns]

# %%
ax, fig = plt.subplots(1,3, figsize=(15,5))
fig[0].set_title('G loss')
dfG.plot(ax=fig[0])
fig[1].set_title('D loss')
dfD.plot(ax=fig[1])
fig[2].set_title('Noise Amplitude')
dfNoise.plot(ax=fig[2])
# Out:
# <Axes: title={'center': 'Noise Amplitude'}>
